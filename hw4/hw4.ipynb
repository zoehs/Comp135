# %% [markdown]
# # HW4 Trees, Forests, and Bag of Words
#
# Official instructions:
#
# https://www.cs.tufts.edu/comp/135/2020f/hw4.html
#
# This is the *starter code* notebook.

# %%
import numpy as np
import pandas as pd
import os
import sys
import time

# %%
import sklearn.tree
import sklearn.linear_model
import sklearn.metrics
import sklearn.ensemble

# %%
# From the HW4 starter code
from pretty_print_sklearn_tree import pretty_print_sklearn_tree

# %%
# Plotting utils
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('seaborn') # pretty matplotlib plots

import seaborn as sns
sns.set('notebook', font_scale=1.25, style='whitegrid')

# %% [markdown]
# # Load all data from train/valid/test

# %%
# TODO fix to path on your local system
DATA_DIR = '/users/zoehsieh/Desktop/Comp135/hw4/data_product_reviews/'

# %% [markdown]
# ### Load training

# %%
x_tr_df = pd.read_csv(os.path.join(DATA_DIR, 'x_train.csv.zip'))
y_tr_df = pd.read_csv(os.path.join(DATA_DIR, 'y_train.csv'))
x_tr_NF = np.minimum(x_tr_df.values, 1.0).copy()
y_tr_N = y_tr_df.values[:,0].copy()

print("Training data")
print("x_tr_NF.shape: %s" % str(x_tr_NF.shape))
print("y_tr_N.shape : %s" % str(y_tr_N.shape))
print("mean(y_tr_N) : %.3f" % np.mean(y_tr_N))
# Out:
# Training data
# x_tr_NF.shape: (6346, 7729)
# y_tr_N.shape : (6346,)
# mean(y_tr_N) : 0.500

# %% [markdown]
# ### Load validation set

# %%
x_va_df = pd.read_csv(os.path.join(DATA_DIR, 'x_valid.csv.zip'))
y_va_df = pd.read_csv(os.path.join(DATA_DIR, 'y_valid.csv'))

x_va_TF = np.minimum(x_va_df.values, 1.0).copy()
y_va_T = y_va_df.values[:,0].copy()

print("Validation data")
print("x_va_TF.shape: %s" % str(x_va_TF.shape))
print("y_va_T.shape : %s" % str(y_va_T.shape))
print("mean(y_va_T) : %.3f" % np.mean(y_va_T))
# Out:
# Validation data
# x_va_TF.shape: (792, 7729)
# y_va_T.shape : (792,)
# mean(y_va_T) : 0.490

# %% [markdown]
# ### Load test set

# %%
x_te_df = pd.read_csv(os.path.join(DATA_DIR, 'x_test.csv.zip'))
y_te_df = pd.read_csv(os.path.join(DATA_DIR, 'y_test.csv'))

x_te_TF = np.minimum(x_te_df.values, 1.0).copy()
y_te_T = y_te_df.values[:,0].copy()

print("Heldout Test data")
print("x_te_TF.shape: %s" % str(x_te_TF.shape))
print("y_te_T.shape : %s" % str(y_te_T.shape))
print("mean(y_te_T) : %.3f" % np.mean(y_te_T))
# Out:
# Heldout Test data
# x_te_TF.shape: (793, 7729)
# y_te_T.shape : (793,)
# mean(y_te_T) : 0.515

# %% [markdown]
# ### Load vocabulary as a list of strings

# %%
vocab_list = x_tr_df.columns.tolist()

# %%
for word in vocab_list[:8]:
    print(word)
print("...")
for word in vocab_list[-8:]:
    print(word)
# Out:
# good
# great
# time
# book
# don't
# work
# i_have
# read
# ...
# never_get
# i'd_like
# loves_it
# an_author
# nomin
# could_give
# bad_but
# gap

# %% [markdown]
# ### Pack training and validation sets into big arrays (so we can use sklearn's hyperparameter search tools)

# %%
xall_LF = np.vstack([x_tr_NF, x_va_TF])
yall_L = np.hstack([y_tr_N, y_va_T])

# %%
valid_indicators_L = np.hstack([
    -1 * np.ones(y_tr_N.size), # -1 means never include this example in any test split
    0  * np.ones(y_va_T.size), #  0 means include in the first test split (we count starting at 0 in python)
    ])

# %%
# Create splitter object using Predefined Split
# Will be used later by all hyperparameter searches

my_splitter = sklearn.model_selection.PredefinedSplit(valid_indicators_L)

# %% [markdown]
# # Problem 1: Decision Trees
#
# ## 1A: Train a simple tree with depth 3

# %%
simple_tree = sklearn.tree.DecisionTreeClassifier(
    max_depth=3, min_samples_split=2, min_samples_leaf=1, criterion='gini')

# %% [markdown]
# ### **Fit the tree**
#
# **TODO Train on the training set** in the next coding cell

# %%
simple_tree.fit(x_tr_NF, y_tr_N) #TODO
# Out:
# DecisionTreeClassifier(max_depth=3)

# %% [markdown]
# ### **Print Tree**
#
# Use a helper function from the starter code

# %%
pretty_print_sklearn_tree(simple_tree, feature_names=vocab_list)
# Out:
# The binary tree structure has 15 nodes.
# - depth   0 has    1 nodes, of which    0 are leaves
# - depth   1 has    2 nodes, of which    0 are leaves
# - depth   2 has    4 nodes, of which    0 are leaves
# - depth   3 has    8 nodes, of which    8 are leaves
# The decision tree:  (Note: Y = 'yes' to above question; N = 'no')
# Decision: X['great'] <= 0.50?
#   Y Decision: X['excel'] <= 0.50?
#     Y Decision: X['disappoint'] <= 0.50?
#       Y Leaf: p(y=1 | this leaf) = 0.430 (4041 total training examples)
#       N Leaf: p(y=1 | this leaf) = 0.114 (368 total training examples)
#     N Decision: X['disappoint'] <= 0.50?
#       Y Leaf: p(y=1 | this leaf) = 0.903 (277 total training examples)
#       N Leaf: p(y=1 | this leaf) = 0.429 (14 total training examples)
#   N Decision: X['return'] <= 0.50?
#     Y Decision: X['bad'] <= 0.50?
#       Y Leaf: p(y=1 | this leaf) = 0.745 (1413 total training examples)
#       N Leaf: p(y=1 | this leaf) = 0.415 (142 total training examples)
#     N Decision: X['movie'] <= 0.50?
#       Y Leaf: p(y=1 | this leaf) = 0.190 (79 total training examples)
#       N Leaf: p(y=1 | this leaf) = 0.833 (12 total training examples)

# %% [markdown]
# ## 1B : Find best Decision Tree with grid search

# %%
# Construct the default predictor
# Any hyperparameters here may be overridden by the hyperparameter grid

tree = sklearn.tree.DecisionTreeClassifier(
    criterion='gini', min_samples_split=2, min_samples_leaf=1)

# %%
tree_hyperparameter_grid_by_name = dict(
    max_depth=[2, 8, 32, 128],
    min_samples_leaf=[1, 3, 9],
    random_state = [101],
    )

# %% [markdown]
# **TODO Build the Grid Search** in the next coding cell
#
# Hint: See Lab for Grid Search: https://github.com/tufts-ml-courses/comp135-20f-assignments/blob/master/labs/day13_HyperparameterSearch.ipynb
#
# Key Function: sklearn.model_selection.GridSearchCV
#
# Key Requirements:
#
# * Provide the above tree_hyperparameter_grid_by_name dictionary as the set of hyperparameters to search
# * Set scoring='balanced_accuracy', since our target metric is balanced accuracy
# * Set cv=my_splitter so you can use the predefined split we defined earlier.
# * Set return_train_score=True (we want training set scores as well as test set scores)
# * Set refit=False (we only want fits on x_tr not on x_all)

# %%
tree_grid_searcher = sklearn.model_selection.GridSearchCV(
    simple_tree,
    tree_hyperparameter_grid_by_name,
    scoring='balanced_accuracy',
    cv=my_splitter,
    return_train_score=True,
    refit=False)

# %% [markdown]
# ### Do the search!

# %%
start_time_sec = time.time()
tree_grid_searcher.fit(xall_LF, yall_L)
elapsed_time_sec = time.time() - start_time_sec

# %% [markdown]
# ### Build dataframe of results
#
# Move the results of grid search into a nice pandas data frame.

# %%
tree_search_results_df = pd.DataFrame(tree_grid_searcher.cv_results_).copy()
print("Grid search of %3d configurations done after %6.1f sec" % (
    tree_search_results_df.shape[0], elapsed_time_sec))
# Out:
# Grid search of  12 configurations done after  144.4 sec

# %% [markdown]
# ### Display search results
#
# This block will make a pretty printed table of the results of your grid search

# %%
pd.set_option('precision', 4)
tree_keys = ['param_max_depth', 'param_min_samples_leaf']
tree_search_results_df.sort_values(tree_keys, inplace=True)
tree_search_results_df[tree_keys + ['mean_train_score', 'mean_test_score', 'rank_test_score', 'mean_fit_time']]
# Out:
#    param_max_depth param_min_samples_leaf  mean_train_score  mean_test_score  \
# 0                2                      1            0.6404           0.6339
# 1                2                      3            0.6404           0.6339
# 2                2                      9            0.6404           0.6339
# 3                8                      1            0.7279           0.6989
# 4                8                      3            0.7232           0.6978
# 5                8                      9            0.7123           0.6962
# 6               32                      1            0.9187           0.7325
# 7               32                      3            0.8752           0.7349
# 8               32                      9            0.8121           0.7197
# 9              128                      1            0.9981           0.7366
# 10             128                      3            0.9255           0.7274
# 11             128                      9            0.8308           0.7296
#
#     rank_test_score  mean_fit_time
# 0                10         2.9640
# 1                10         2.4456
# 2                10         2.2847
# 3                 7         6.7511
# 4                 8         7.3906
# 5                 9         6.8500
# 6                 3        16.2346
# 7                 2        15.6196
# 8                 6        14.7058
# 9                 1        27.5890
# 10                5        21.1931
# 11                4        16.5473

# %%
print("Printing a dict of the best hyperparameters")
print(tree_grid_searcher.best_params_)
# Out:
# Printing a dict of the best hyperparameters
# {'max_depth': 128, 'min_samples_leaf': 1, 'random_state': 101}

# %% [markdown]
# ### Build the best decision tree

# %% [markdown]
# **TODO Build the Best Tree** in the next coding cell
#
# This is necessary so you have the specific best performing tree in your workspace.
#
# Although you fit many trees in the search, they were not stored, so we need to recreate the best one.
#
# Hint: Just feed the best hyperparameters as keyword args to construct the tree. Or see the lab about grid search.

# %%
best_tree = tree.set_params(max_depth=128, min_samples_leaf=1, random_state=101) #TODO
best_tree.fit(x_tr_NF, y_tr_N)
# Out:
# DecisionTreeClassifier(max_depth=128, random_state=101)

# %% [markdown]
# ### Interpret the best decision tree

# %%
best_tree.tree_

# %%
pretty_print_sklearn_tree(best_tree, feature_names=vocab_list)
# Out:
# The binary tree structure has 1587 nodes.
# - depth   0 has    1 nodes, of which    0 are leaves
# - depth   1 has    2 nodes, of which    0 are leaves
# - depth   2 has    4 nodes, of which    0 are leaves
# - depth   3 has    8 nodes, of which    0 are leaves
# - depth   4 has   16 nodes, of which    5 are leaves
# - depth   5 has   22 nodes, of which    6 are leaves
# - depth   6 has   32 nodes, of which   13 are leaves
# - depth   7 has   38 nodes, of which   21 are leaves
# - depth   8 has   34 nodes, of which   16 are leaves
# - depth   9 has   36 nodes, of which   13 are leaves
# - depth  10 has   46 nodes, of which   23 are leaves
# - depth  11 has   46 nodes, of which   26 are leaves
# - depth  12 has   40 nodes, of which   17 are leaves
# - depth  13 has   46 nodes, of which   25 are leaves
# - depth  14 has   42 nodes, of which   24 are leaves
# - depth  15 has   36 nodes, of which   18 are leaves
# - depth  16 has   36 nodes, of which   16 are leaves
# - depth  17 has   40 nodes, of which   22 are leaves
# - depth  18 has   36 nodes, of which   20 are leaves
# - depth  19 has   32 nodes, of which   16 are leaves
# - depth  20 has   32 nodes, of which   13 are leaves
# - depth  21 has   38 nodes, of which   19 are leaves
# - depth  22 has   38 nodes, of which   19 are leaves
# - depth  23 has   38 nodes, of which   23 are leaves
# - depth  24 has   30 nodes, of which   18 are leaves
# - depth  25 has   24 nodes, of which   10 are leaves
# - depth  26 has   28 nodes, of which   16 are leaves
# - depth  27 has   24 nodes, of which   15 are leaves
# - depth  28 has   18 nodes, of which    8 are leaves
# - depth  29 has   20 nodes, of which   10 are leaves
# - depth  30 has   20 nodes, of which    8 are leaves
# - depth  31 has   24 nodes, of which   16 are leaves
# - depth  32 has   16 nodes, of which    7 are leaves
# - depth  33 has   18 nodes, of which   10 are leaves
# - depth  34 has   16 nodes, of which    6 are leaves
# - depth  35 has   20 nodes, of which   12 are leaves
# - depth  36 has   16 nodes, of which    8 are leaves
# - depth  37 has   16 nodes, of which    8 are leaves
# - depth  38 has   16 nodes, of which    8 are leaves
# - depth  39 has   16 nodes, of which   10 are leaves
# - depth  40 has   12 nodes, of which    6 are leaves
# - depth  41 has   12 nodes, of which    5 are leaves
# - depth  42 has   14 nodes, of which    4 are leaves
# - depth  43 has   20 nodes, of which   11 are leaves
# - depth  44 has   18 nodes, of which   10 are leaves
# - depth  45 has   16 nodes, of which   10 are leaves
# - depth  46 has   12 nodes, of which    8 are leaves
# - depth  47 has    8 nodes, of which    4 are leaves
# - depth  48 has    8 nodes, of which    3 are leaves
# - depth  49 has   10 nodes, of which    6 are leaves
# - depth  50 has    8 nodes, of which    4 are leaves
# - depth  51 has    8 nodes, of which    5 are leaves
# - depth  52 has    6 nodes, of which    3 are leaves
# - depth  53 has    6 nodes, of which    3 are leaves
# - depth  54 has    6 nodes, of which    3 are leaves
# - depth  55 has    6 nodes, of which    3 are leaves
# - depth  56 has    6 nodes, of which    3 are leaves
# - depth  57 has    6 nodes, of which    2 are leaves
# - depth  58 has    8 nodes, of which    4 are leaves
# - depth  59 has    8 nodes, of which    5 are leaves
# - depth  60 has    6 nodes, of which    3 are leaves
# - depth  61 has    6 nodes, of which    3 are leaves
# - depth  62 has    6 nodes, of which    2 are leaves
# - depth  63 has    8 nodes, of which    5 are leaves
# - depth  64 has    6 nodes, of which    3 are leaves
# - depth  65 has    6 nodes, of which    3 are leaves
# - depth  66 has    6 nodes, of which    2 are leaves
# - depth  67 has    8 nodes, of which    3 are leaves
# - depth  68 has   10 nodes, of which    5 are leaves
# - depth  69 has   10 nodes, of which    8 are leaves
# - depth  70 has    4 nodes, of which    2 are leaves
# - depth  71 has    4 nodes, of which    1 are leaves
# - depth  72 has    6 nodes, of which    1 are leaves
# - depth  73 has   10 nodes, of which    6 are leaves
# - depth  74 has    8 nodes, of which    4 are leaves
# - depth  75 has    8 nodes, of which    4 are leaves
# - depth  76 has    8 nodes, of which    4 are leaves
# - depth  77 has    8 nodes, of which    5 are leaves
# - depth  78 has    6 nodes, of which    3 are leaves
# - depth  79 has    6 nodes, of which    3 are leaves
# - depth  80 has    6 nodes, of which    3 are leaves
# - depth  81 has    6 nodes, of which    3 are leaves
# - depth  82 has    6 nodes, of which    3 are leaves
# - depth  83 has    6 nodes, of which    3 are leaves
# - depth  84 has    6 nodes, of which    3 are leaves
# - depth  85 has    6 nodes, of which    1 are leaves
# - depth  86 has   10 nodes, of which    7 are leaves
# - depth  87 has    6 nodes, of which    3 are leaves
# - depth  88 has    6 nodes, of which    4 are leaves
# - depth  89 has    4 nodes, of which    3 are leaves
# - depth  90 has    2 nodes, of which    0 are leaves
# - depth  91 has    4 nodes, of which    2 are leaves
# - depth  92 has    4 nodes, of which    3 are leaves
# - depth  93 has    2 nodes, of which    1 are leaves
# - depth  94 has    2 nodes, of which    0 are leaves
# - depth  95 has    4 nodes, of which    2 are leaves
# - depth  96 has    4 nodes, of which    1 are leaves
# - depth  97 has    6 nodes, of which    3 are leaves
# - depth  98 has    6 nodes, of which    3 are leaves
# - depth  99 has    6 nodes, of which    4 are leaves
# - depth 100 has    4 nodes, of which    2 are leaves
# - depth 101 has    4 nodes, of which    1 are leaves
# - depth 102 has    6 nodes, of which    3 are leaves
# - depth 103 has    6 nodes, of which    4 are leaves
# - depth 104 has    4 nodes, of which    2 are leaves
# - depth 105 has    4 nodes, of which    2 are leaves
# - depth 106 has    4 nodes, of which    2 are leaves
# - depth 107 has    4 nodes, of which    2 are leaves
# - depth 108 has    4 nodes, of which    2 are leaves
# - depth 109 has    4 nodes, of which    2 are leaves
# - depth 110 has    4 nodes, of which    2 are leaves
# - depth 111 has    4 nodes, of which    3 are leaves
# - depth 112 has    2 nodes, of which    1 are leaves
# - depth 113 has    2 nodes, of which    1 are leaves
# - depth 114 has    2 nodes, of which    1 are leaves
# - depth 115 has    2 nodes, of which    1 are leaves
# - depth 116 has    2 nodes, of which    1 are leaves
# - depth 117 has    2 nodes, of which    1 are leaves
# - depth 118 has    2 nodes, of which    1 are leaves
# - depth 119 has    2 nodes, of which    1 are leaves
# - depth 120 has    2 nodes, of which    1 are leaves
# - depth 121 has    2 nodes, of which    1 are leaves
# - depth 122 has    2 nodes, of which    1 are leaves
# - depth 123 has    2 nodes, of which    1 are leaves
# - depth 124 has    2 nodes, of which    1 are leaves
# - depth 125 has    2 nodes, of which    1 are leaves
# - depth 126 has    2 nodes, of which    1 are leaves
# - depth 127 has    2 nodes, of which    1 are leaves
# - depth 128 has    2 nodes, of which    2 are leaves
# The decision tree:  (Note: Y = 'yes' to above question; N = 'no')
# Decision: X['great'] <= 0.50?
#   Y Decision: X['excel'] <= 0.50?
#     Y Decision: X['disappoint'] <= 0.50?
#       Y Decision: X['easy'] <= 0.50?
#         Y Decision: X['love'] <= 0.50?
#           Y Decision: X['waste'] <= 0.50?
#             Y Decision: X['bad'] <= 0.50?
#               Y Decision: X['poor'] <= 0.50?
#                 Y Decision: X['the_best'] <= 0.50?
#                   Y Decision: X['return'] <= 0.50?
#                     Y Decision: X['perfect'] <= 0.50?
#                       Y Decision: X['worst'] <= 0.50?
#                         Y Decision: X['bore'] <= 0.50?
#                           Y Decision: X['enjoy'] <= 0.50?
#                             Y Decision: X['a_must'] <= 0.50?
#                               Y Decision: X['highly_recommend'] <= 0.50?
#                                 Y Decision: X['amaz'] <= 0.50?
#                                   Y Decision: X['good'] <= 0.50?
#                                     Y Decision: X['loved'] <= 0.50?
#                                       Y Decision: X['beauti'] <= 0.50?
#                                         Y Decision: X['univers'] <= 0.50?
#                                           Y Decision: X['knowledg'] <= 0.50?
#                                             Y Decision: X['well_worth'] <= 0.50?
#                                               Y Decision: X['favorit'] <= 0.50?
#                                                 Y Decision: X['back'] <= 0.50?
#                                                   Y Decision: X['smooth'] <= 0.50?
#                                                     Y Decision: X['wonder'] <= 0.50?
#                                                       Y Decision: X['am_very'] <= 0.50?
#                                                         Y Decision: X['outstand'] <= 0.50?
#                                                           Y Decision: X['complex'] <= 0.50?
#                                                             Y Decision: X['fantast'] <= 0.50?
#                                                               Y Decision: X['work'] <= 0.50?
#                                                                 Y Decision: X['when_i'] <= 0.50?
#                                                                   Y Decision: X['heart'] <= 0.50?
#                                                                     Y Decision: X['analysi'] <= 0.50?
#                                                                       Y Decision: X['works'] <= 0.50?
#                                                                         Y Decision: X['the_job'] <= 0.50?
#                                                                           Y Decision: X['of_our'] <= 0.50?
#                                                                             Y Decision: X['very_nice'] <= 0.50?
#                                                                               Y Decision: X['ways'] <= 0.50?
#                                                                                 Y Decision: X['loves_it'] <= 0.50?
#                                                                                   Y Decision: X['entir'] <= 0.50?
#                                                                                     Y Decision: X['be_used'] <= 0.50?
#                                                                                       Y Decision: X['trip'] <= 0.50?
#                                                                                         Y Decision: X['glad'] <= 0.50?
#                                                                                           Y Decision: X['equip'] <= 0.50?
#                                                                                             Y Decision: X['brother'] <= 0.50?
#                                                                                               Y Decision: X['study'] <= 0.50?
#                                                                                                 Y Decision: X['can_you'] <= 0.50?
#                                                                                                   Y Decision: X['them_for'] <= 0.50?
#                                                                                                     Y Decision: X['tool'] <= 0.50?
#                                                                                                       Y Decision: X['to_another'] <= 0.50?
#                                                                                                         Y Decision: X['deeper'] <= 0.50?
#                                                                                                           Y Decision: X['just_want'] <= 0.50?
#                                                                                                             Y Decision: X['partner'] <= 0.50?
#                                                                                                               Y Decision: X['winner'] <= 0.50?
#                                                                                                                 Y Decision: X['highly_recommended'] <= 0.50?
#                                                                                                                   Y Decision: X['a_hard'] <= 0.50?
#                                                                                                                     Y Decision: X['for_many'] <= 0.50?
#                                                                                                                       Y Decision: X['foam'] <= 0.50?
#                                                                                                                         Y Decision: X['seen_it'] <= 0.50?
#                                                                                                                           Y Decision: X['who_are'] <= 0.50?
#                                                                                                                             Y Decision: X['satisfi'] <= 0.50?
#                                                                                                                               Y Decision: X['woman'] <= 0.50?
#                                                                                                                                 Y Decision: X['chapter'] <= 0.50?
#                                                                                                                                   Y Decision: X['superb'] <= 0.50?
#                                                                                                                                     Y Decision: X['book_for'] <= 0.50?
#                                                                                                                                       Y Decision: X['the_ones'] <= 0.50?
#                                                                                                                                         Y Decision: X['and_your'] <= 0.50?
#                                                                                                                                           Y Decision: X['for_your'] <= 0.50?
#                                                                                                                                             Y Decision: X['don't'] <= 0.50?
#                                                                                                                                               Y Decision: X['daughter'] <= 0.50?
#                                                                                                                                                 Y Decision: X['cold'] <= 0.50?
#                                                                                                                                                   Y Decision: X['just_that'] <= 0.50?
#                                                                                                                                                     Y Decision: X['items'] <= 0.50?
#                                                                                                                                                       Y Decision: X['never_have'] <= 0.50?
#                                                                                                                                                         Y Decision: X['it_while'] <= 0.50?
#                                                                                                                                                           Y Decision: X['mountain'] <= 0.50?
#                                                                                                                                                             Y Decision: X['even_more'] <= 0.50?
#                                                                                                                                                               Y Decision: X['not_quite'] <= 0.50?
#                                                                                                                                                                 Y Decision: X['to_give'] <= 0.50?
#                                                                                                                                                                   Y Decision: X['go_for'] <= 0.50?
#                                                                                                                                                                     Y Decision: X['well_made'] <= 0.50?
#                                                                                                                                                                       Y Decision: X['for_several'] <= 0.50?
#                                                                                                                                                                         Y Decision: X['valuabl'] <= 0.50?
#                                                                                                                                                                           Y Decision: X['my_review'] <= 0.50?
#                                                                                                                                                                             Y Decision: X['it_gives'] <= 0.50?
#                                                                                                                                                                               Y Decision: X['i_say'] <= 0.50?
#                                                                                                                                                                                 Y Decision: X['5'] <= 0.50?
#                                                                                                                                                                                   Y Decision: X['movie'] <= 0.50?
#                                                                                                                                                                                     Y Decision: X['intrigu'] <= 0.50?
#                                                                                                                                                                                       Y Decision: X['you_feel'] <= 0.50?
#                                                                                                                                                                                         Y Decision: X['breath'] <= 0.50?
#                                                                                                                                                                                           Y Decision: X['awesom'] <= 0.50?
#                                                                                                                                                                                             Y Decision: X['world'] <= 0.50?
#                                                                                                                                                                                               Y Decision: X['pretti'] <= 0.50?
#                                                                                                                                                                                                 Y Decision: X['you_would'] <= 0.50?
#                                                                                                                                                                                                   Y Decision: X['thrill'] <= 0.50?
#                                                                                                                                                                                                     Y Decision: X['success'] <= 0.50?
#                                                                                                                                                                                                       Y Decision: X['collect'] <= 0.50?
#                                                                                                                                                                                                         Y Decision: X['the_next'] <= 0.50?
#                                                                                                                                                                                                           Y Decision: X['for_less'] <= 0.50?
#                                                                                                                                                                                                             Y Decision: X['continu'] <= 0.50?
#                                                                                                                                                                                                               Y Decision: X['space'] <= 0.50?
#                                                                                                                                                                                                                 Y Decision: X['1'] <= 0.50?
#                                                                                                                                                                                                                   Y Decision: X['dvds'] <= 0.50?
#                                                                                                                                                                                                                     Y Decision: X['even'] <= 0.50?
#                                                                                                                                                                                                                       Y Decision: X['a_friend'] <= 0.50?
#                                                                                                                                                                                                                         Y Decision: X['perform'] <= 0.50?
#                                                                                                                                                                                                                           Y Decision: X['other_words'] <= 0.50?
#                                                                                                                                                                                                                             Y Decision: X['as_he'] <= 0.50?
#                                                                                                                                                                                                                               Y Decision: X['center'] <= 0.50?
#                                                                                                                                                                                                                                 Y Decision: X['heavy_and'] <= 0.50?
#                                                                                                                                                                                                                                   Y Decision: X['why_this'] <= 0.50?
#                                                                                                                                                                                                                                     Y Decision: X['mini'] <= 0.50?
#                                                                                                                                                                                                                                       Y Decision: X['are_made'] <= 0.50?
#                                                                                                                                                                                                                                         Y Decision: X['phone_and'] <= 0.50?
#                                                                                                                                                                                                                                           Y Decision: X['the_wireless'] <= 0.50?
#                                                                                                                                                                                                                                             Y Decision: X['wed'] <= 0.50?
#                                                                                                                                                                                                                                               Y Decision: X['forev'] <= 0.50?
#                                                                                                                                                                                                                                                 Y Decision: X['de'] <= 0.50?
#                                                                                                                                                                                                                                                   Y Decision: X['would_get'] <= 0.50?
#                                                                                                                                                                                                                                                     Y Decision: X['see_in'] <= 0.50?
#                                                                                                                                                                                                                                                       Y Decision: X['very_comfortable'] <= 0.50?
#                                                                                                                                                                                                                                                         Y Decision: X['spoon'] <= 0.50?
#                                                                                                                                                                                                                                                           Y Decision: X['anything_that'] <= 0.50?
#                                                                                                                                                                                                                                                             Y Decision: X['who'] <= 0.50?
#                                                                                                                                                                                                                                                               Y Decision: X['dialogu'] <= 0.50?
#                                                                                                                                                                                                                                                                 Y Leaf: p(y=1 | this leaf) = 0.031 (383 total training examples)
#                                                                                                                                                                                                                                                                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                                               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                                             N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                                         N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                                       N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                                     N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                             N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                         N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                       N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                     N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                             N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                           N Decision: X['better_than'] <= 0.50?
#                                                                                                                                                                                                                             Y Decision: X['product'] <= 0.50?
#                                                                                                                                                                                                                               Y Leaf: p(y=1 | this leaf) = 0.000 (4 total training examples)
#                                                                                                                                                                                                                               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                             N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                                                                         N Decision: X['characters_are'] <= 0.50?
#                                                                                                                                                                                                                           Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                                                                           N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                                                                       N Decision: X['suffici'] <= 0.50?
#                                                                                                                                                                                                                         Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                                                                         N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                                                                     N Decision: X['at_amazon'] <= 0.50?
#                                                                                                                                                                                                                       Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                                                                       N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                                                                   N Decision: X['2'] <= 0.50?
#                                                                                                                                                                                                                     Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                                                                     N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                                                                 N Decision: X['go_to'] <= 0.50?
#                                                                                                                                                                                                                   Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                                                                   N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                                                               N Decision: X['music'] <= 0.50?
#                                                                                                                                                                                                                 Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                                                                 N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                                                             N Decision: X['price_of'] <= 0.50?
#                                                                                                                                                                                                               Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                                                               N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                                                           N Decision: X['time'] <= 0.50?
#                                                                                                                                                                                                             Y Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                                                                                                                                                                                                             N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#                                                                                                                                                                                                         N Decision: X['times'] <= 0.50?
#                                                                                                                                                                                                           Y Decision: X['design_and'] <= 0.50?
#                                                                                                                                                                                                             Y Decision: X['lover'] <= 0.50?
#                                                                                                                                                                                                               Y Leaf: p(y=1 | this leaf) = 0.000 (4 total training examples)
#                                                                                                                                                                                                               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                             N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                           N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                                                       N Decision: X['found_the'] <= 0.50?
#                                                                                                                                                                                                         Y Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                                                                                                                                                                                                         N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#                                                                                                                                                                                                     N Decision: X['devil'] <= 0.50?
#                                                                                                                                                                                                       Y Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                                                                                                                                                                                                       N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#                                                                                                                                                                                                   N Decision: X['hand'] <= 0.50?
#                                                                                                                                                                                                     Y Decision: X['block'] <= 0.50?
#                                                                                                                                                                                                       Y Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                                                                                                                                                                                                       N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                                                     N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                                                 N Decision: X['film'] <= 0.50?
#                                                                                                                                                                                                   Y Decision: X['notic'] <= 0.50?
#                                                                                                                                                                                                     Y Leaf: p(y=1 | this leaf) = 1.000 (5 total training examples)
#                                                                                                                                                                                                     N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                                                   N Leaf: p(y=1 | this leaf) = 0.000 (3 total training examples)
#                                                                                                                                                                                               N Decision: X['all_you'] <= 0.50?
#                                                                                                                                                                                                 Y Decision: X['million'] <= 0.50?
#                                                                                                                                                                                                   Y Leaf: p(y=1 | this leaf) = 1.000 (4 total training examples)
#                                                                                                                                                                                                   N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
# ...
#                                                         Y Leaf: p(y=1 | this leaf) = 0.000 (4 total training examples)
#                                                         N Decision: X['a_certain'] <= 0.50?
#                                                           Y Leaf: p(y=1 | this leaf) = 1.000 (4 total training examples)
#                                                           N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                     N Decision: X['months_now'] <= 0.50?
#                                                       Y Leaf: p(y=1 | this leaf) = 0.000 (4 total training examples)
#                                                       N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                   N Decision: X['i'm'] <= 0.50?
#                                                     Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                     N Leaf: p(y=1 | this leaf) = 0.000 (4 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.000 (3 total training examples)
#                                               N Leaf: p(y=1 | this leaf) = 0.000 (3 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 0.000 (3 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 0.000 (3 total training examples)
#                                         N Decision: X['charg'] <= 0.50?
#                                           Y Decision: X['water_and'] <= 0.50?
#                                             Y Decision: X['takes'] <= 0.50?
#                                               Y Leaf: p(y=1 | this leaf) = 0.000 (7 total training examples)
#                                               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                                       N Decision: X['and_i'] <= 0.50?
#                                         Y Leaf: p(y=1 | this leaf) = 0.000 (5 total training examples)
#                                         N Decision: X['worth_it'] <= 0.50?
#                                           Y Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                     N Decision: X['that_i'] <= 0.50?
#                                       Y Decision: X['a_month'] <= 0.50?
#                                         Y Decision: X['use_it'] <= 0.50?
#                                           Y Leaf: p(y=1 | this leaf) = 0.000 (8 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                         N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 1.000 (4 total training examples)
#                                   N Decision: X['earth'] <= 0.50?
#                                     Y Leaf: p(y=1 | this leaf) = 0.000 (6 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                 N Decision: X['impress'] <= 0.50?
#                                   Y Decision: X['i_learned'] <= 0.50?
#                                     Y Leaf: p(y=1 | this leaf) = 0.000 (7 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                               N Decision: X['for_your'] <= 0.50?
#                                 Y Leaf: p(y=1 | this leaf) = 0.000 (7 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.000 (5 total training examples)
#                           N Decision: X['person'] <= 0.50?
#                             Y Decision: X['than_this'] <= 0.50?
#                               Y Leaf: p(y=1 | this leaf) = 0.000 (9 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                         N Decision: X['you_don't'] <= 0.50?
#                           Y Leaf: p(y=1 | this leaf) = 0.000 (8 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                       N Decision: X['i've'] <= 0.50?
#                         Y Decision: X['don't'] <= 0.50?
#                           Y Decision: X['impossible_to'] <= 0.50?
#                             Y Leaf: p(y=1 | this leaf) = 0.000 (15 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                           N Decision: X['is_not'] <= 0.50?
#                             Y Leaf: p(y=1 | this leaf) = 1.000 (7 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 1.000 (5 total training examples)
#                     N Decision: X['his_wife'] <= 0.50?
#                       Y Leaf: p(y=1 | this leaf) = 0.000 (10 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                   N Decision: X['a_good'] <= 0.50?
#                     Y Decision: X['because_i'] <= 0.50?
#                       Y Decision: X['that_<num>'] <= 0.50?
#                         Y Decision: X['get_this'] <= 0.50?
#                           Y Leaf: p(y=1 | this leaf) = 0.000 (16 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                     N Decision: X['final'] <= 0.50?
#                       Y Leaf: p(y=1 | this leaf) = 1.000 (5 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                 N Decision: X['day'] <= 0.50?
#                   Y Decision: X['throughout_the'] <= 0.50?
#                     Y Decision: X['anyone_else'] <= 0.50?
#                       Y Leaf: p(y=1 | this leaf) = 0.000 (14 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#               N Leaf: p(y=1 | this leaf) = 0.000 (8 total training examples)
#             N Decision: X['years'] <= 0.50?
#               Y Decision: X['cook'] <= 0.50?
#                 Y Decision: X['to_get'] <= 0.50?
#                   Y Decision: X['you_need'] <= 0.50?
#                     Y Decision: X['found'] <= 0.50?
#                       Y Decision: X['the_<num>'] <= 0.50?
#                         Y Decision: X['now_a'] <= 0.50?
#                           Y Decision: X['appar'] <= 0.50?
#                             Y Leaf: p(y=1 | this leaf) = 1.000 (20 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                         N Decision: X['only_for'] <= 0.50?
#                           Y Leaf: p(y=1 | this leaf) = 0.000 (3 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#                   N Decision: X['encount'] <= 0.50?
#                     Y Leaf: p(y=1 | this leaf) = 0.000 (5 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 0.000 (5 total training examples)
#               N Decision: X['heads'] <= 0.50?
#                 Y Leaf: p(y=1 | this leaf) = 0.000 (10 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#           N Decision: X['real'] <= 0.50?
#             Y Decision: X['best_of'] <= 0.50?
#               Y Leaf: p(y=1 | this leaf) = 0.000 (21 total training examples)
#               N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#             N Decision: X['we_see'] <= 0.50?
#               Y Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#               N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#         N Decision: X['be_disappointed'] <= 0.50?
#           Y Decision: X['was_not'] <= 0.50?
#             Y Decision: X['field'] <= 0.50?
#               Y Decision: X['of_my'] <= 0.50?
#                 Y Decision: X['excel'] <= 0.50?
#                   Y Decision: X['compel'] <= 0.50?
#                     Y Decision: X['child'] <= 0.50?
#                       Y Decision: X['can't_go'] <= 0.50?
#                         Y Decision: X['satisfied_with'] <= 0.50?
#                           Y Decision: X['read_all'] <= 0.50?
#                             Y Decision: X['think_of'] <= 0.50?
#                               Y Decision: X['this_series'] <= 0.50?
#                                 Y Decision: X['quart'] <= 0.50?
#                                   Y Decision: X['highly_recommended'] <= 0.50?
#                                     Y Leaf: p(y=1 | this leaf) = 0.000 (46 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#               N Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#             N Decision: X['not_really'] <= 0.50?
#               Y Leaf: p(y=1 | this leaf) = 1.000 (8 total training examples)
#               N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#           N Decision: X['to_record'] <= 0.50?
#             Y Leaf: p(y=1 | this leaf) = 1.000 (9 total training examples)
#             N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#       N Decision: X['is_really'] <= 0.50?
#         Y Decision: X['run'] <= 0.50?
#           Y Decision: X['the_best'] <= 0.50?
#             Y Decision: X['dvd'] <= 0.50?
#               Y Decision: X['i_love'] <= 0.50?
#                 Y Decision: X['one_on'] <= 0.50?
#                   Y Decision: X['cook'] <= 0.50?
#                     Y Decision: X['excel'] <= 0.50?
#                       Y Decision: X['kids'] <= 0.50?
#                         Y Decision: X['cabl'] <= 0.50?
#                           Y Decision: X['to_learn'] <= 0.50?
#                             Y Decision: X['to_anyone'] <= 0.50?
#                               Y Decision: X['this_device'] <= 0.50?
#                                 Y Decision: X['book_as'] <= 0.50?
#                                   Y Leaf: p(y=1 | this leaf) = 0.000 (69 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                             N Decision: X['didn't'] <= 0.50?
#                               Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                           N Decision: X['a_big'] <= 0.50?
#                             Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                     N Decision: X['also_have'] <= 0.50?
#                       Y Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                 N Decision: X['good_one'] <= 0.50?
#                   Y Leaf: p(y=1 | this leaf) = 1.000 (7 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#               N Decision: X['work_on'] <= 0.50?
#                 Y Leaf: p(y=1 | this leaf) = 1.000 (6 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#             N Decision: X['act'] <= 0.50?
#               Y Decision: X['based'] <= 0.50?
#                 Y Decision: X['great_if'] <= 0.50?
#                   Y Leaf: p(y=1 | this leaf) = 1.000 (12 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#               N Leaf: p(y=1 | this leaf) = 0.000 (4 total training examples)
#           N Decision: X['sourc'] <= 0.50?
#             Y Leaf: p(y=1 | this leaf) = 1.000 (9 total training examples)
#             N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#         N Leaf: p(y=1 | this leaf) = 1.000 (8 total training examples)
#     N Decision: X['movie'] <= 0.50?
#       Y Decision: X['i_even'] <= 0.50?
#         Y Decision: X['one_of'] <= 0.50?
#           Y Decision: X['exercis'] <= 0.50?
#             Y Decision: X['but_then'] <= 0.50?
#               Y Decision: X['pretty_much'] <= 0.50?
#                 Y Decision: X['is_my'] <= 0.50?
#                   Y Leaf: p(y=1 | this leaf) = 0.000 (63 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#               N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#             N Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#           N Decision: X['work_on'] <= 0.50?
#             Y Leaf: p(y=1 | this leaf) = 1.000 (4 total training examples)
#             N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#         N Leaf: p(y=1 | this leaf) = 1.000 (4 total training examples)
#       N Decision: X['is_not'] <= 0.50?
#         Y Leaf: p(y=1 | this leaf) = 1.000 (10 total training examples)
#         N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)

# %% [markdown]
# # Problem 2: Random forest

# %%
forest = sklearn.ensemble.RandomForestClassifier(
    criterion='gini', min_samples_split=2, random_state=101)

# %% [markdown]
# ## 2A: Best Random Forest via grid search
#
# Follow the instructions and using what you learn in 1B to finish this step.
#
# This block might take 2-10 minutes. (Takes about 2 min on staff Macbook laptops.)
#
# If yours runs significantly longer, try this out on Google Colab instead.

# %%
forest = sklearn.ensemble.RandomForestClassifier(
    n_estimators=125,
    criterion='gini',
    max_depth=15,
    min_samples_split=2,
    min_samples_leaf=1)

# %%
forest_hyperparameter_grid_by_name = dict(
    max_features=[3, 10, 33, 100, 333],
    max_depth=[16, 32],
    min_samples_leaf=[1],
    n_estimators=[125],
    random_state=[101],
    )

# %%
# TODO construct a GridSearchCV object like you did above.

forest_searcher = sklearn.model_selection.GridSearchCV(
    forest,
    forest_hyperparameter_grid_by_name,
    scoring='balanced_accuracy',
    cv=my_splitter,
    return_train_score=True,
    refit=False)

# %% [markdown]
# ### Do the search!

# %%
#start_time_sec = time.time()
forest_searcher.fit(xall_LF, yall_L)
elapsed_time_sec = time.time() - start_time_sec

# %% [markdown]
# ### Build dataframe of results

# %%
#TODO
forest_results_df = pd.DataFrame(forest_searcher.cv_results_).copy()
print("Grid search of %3d configurations done after %6.1f sec" % (
    forest_results_df.shape[0], elapsed_time_sec))
# Out:
# Grid search of  10 configurations done after  321.4 sec

# %% [markdown]
# ### Display search results

# %%
#TODO
pd.set_option('precision', 4)
forest_keys = ['param_max_depth', 'param_min_samples_leaf']
forest_results_df.sort_values(forest_keys, inplace=True)
forest_results_df[tree_keys + ['mean_train_score', 'mean_test_score', 'rank_test_score', 'mean_fit_time']]
# Out:
#   param_max_depth param_min_samples_leaf  mean_train_score  mean_test_score  \
# 0              16                      1            0.9289           0.7582
# 1              16                      1            0.9340           0.8550
# 2              16                      1            0.9277           0.8400
# 3              16                      1            0.9217           0.8340
# 4              16                      1            0.8715           0.7942
# 5              32                      1            0.9800           0.8192
# 6              32                      1            0.9751           0.8534
# 7              32                      1            0.9720           0.8448
# 8              32                      1            0.9713           0.8405
# 9              32                      1            0.9527           0.8185
#
#    rank_test_score  mean_fit_time
# 0               10         1.3694
# 1                1         2.1859
# 2                5         5.5440
# 3                6        15.7287
# 4                9        42.4291
# 5                7         1.8146
# 6                2         3.6337
# 7                3         9.2643
# 8                4        22.9902
# 9                8        62.9188

# %% [markdown]
# ### Build the best random forest using the best hyperparameters found in 2B and train it.
#
# This is necessary so you have the specific best performing forest in your workspace.

# %%
#TODO
print("Printing a dict of the best hyperparameters")
print(forest_searcher.best_params_)
# Out:
# Printing a dict of the best hyperparameters
# {'max_depth': 16, 'max_features': 10, 'min_samples_leaf': 1, 'n_estimators': 125, 'random_state': 101}

# %%
best_forest = forest.set_params(max_depth=16, max_features=10, min_samples_leaf=1, n_estimators=125, random_state=101) #TODO
best_forest.fit(x_tr_NF, y_tr_N)
# Out:
# RandomForestClassifier(max_depth=16, max_features=10, n_estimators=125,
#                        random_state=101)

# %% [markdown]
# ## 2B & Figure 2 : Feature Importances
#
# Access the **feature_importances_** attribute of your trained forest to get a score for each term in our vocabulary.
#
# A higher value of this score indicates the feature is "more important".
#
# In one panel of Figure 2, display a list of the top 10 vocabulary words of your best forest with highest feature importance.
#
# In another panel of Figure 2, display a list of 10 randomly chosen terms that have close-to-zero feature importance (use anything with importance less than 0.00001).

# %% [markdown]
# ### Figure 2.2
# **Sample Output** (Feel free to print all words and organize them in any software)
#
# |**Important Words**|**Unimportant Words**|
# |:-:|:-:|
# |I1 |  U1  |
# |I2 |  U2  |
# |I3 |  U3  |
# |I4 |  U4  |
# |I5 |  U5  |
# |I6 |  U6  |
# |I7 |  U7  |
# |I8 |  U8  |
# |I9 |  U9  |
# |I0 |  U0  |

# %%
features = best_forest.feature_importances_

np.asarray(vocab_list)[np.argsort(features)[:10]]
# Out:
# array(['money_to', 'while_you', 'usage', 'kinda', 'factori', 'few_months',
#        'small_and', 'to_carry', 'it_arrived', 'concept_of'], dtype='<U21')

# %%
np.asarray(vocab_list)[np.argsort(features)[-10:]]
# Out:
# array(['disappoint', 'love', 'not_recommend', 'excel', 'bad', 'return',
#        'your_money', 'great', 'poor', 'waste_of'], dtype='<U21')

# %% [markdown]
# # Problem 3: Comparison of models
#
# ### 3A Implementation **TODO**:
#
# Selecting the best logistic regression with L1 penalty
#
# Table 3 in Report

# %%
lasso = sklearn.linear_model.LogisticRegression(
    penalty='l1', solver='saga', random_state=101)

# %%
lasso_hyperparameter_grid_by_name = dict(
    C=np.logspace(-4, 4, 9),
    max_iter=[20, 40], # sneaky way to do "early stopping" 
                       # we'll take either iter 20 or iter 40 in training process, by best valid performance
    )

# %% [markdown]
# #### TODO Selecting the best logistic regression with L1 penalty
# Hint: Follow 1B and 2A

# %%
lasso_searcher = sklearn.model_selection.GridSearchCV(
    lasso,
    lasso_hyperparameter_grid_by_name, 
    scoring='balanced_accuracy',
    cv=my_splitter,
    return_train_score=True,
    refit=False)

# %%
start_time_sec = time.time()
lasso_searcher.fit(xall_LF, yall_L)
elapsed_time_sec = time.time() - start_time_sec
# Out:
# /Users/zoehsieh/opt/miniconda3/envs/comp135_2020f_env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /Users/zoehsieh/opt/miniconda3/envs/comp135_2020f_env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /Users/zoehsieh/opt/miniconda3/envs/comp135_2020f_env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /Users/zoehsieh/opt/miniconda3/envs/comp135_2020f_env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /Users/zoehsieh/opt/miniconda3/envs/comp135_2020f_env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /Users/zoehsieh/opt/miniconda3/envs/comp135_2020f_env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /Users/zoehsieh/opt/miniconda3/envs/comp135_2020f_env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /Users/zoehsieh/opt/miniconda3/envs/comp135_2020f_env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /Users/zoehsieh/opt/miniconda3/envs/comp135_2020f_env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /Users/zoehsieh/opt/miniconda3/envs/comp135_2020f_env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /Users/zoehsieh/opt/miniconda3/envs/comp135_2020f_env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /Users/zoehsieh/opt/miniconda3/envs/comp135_2020f_env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /Users/zoehsieh/opt/miniconda3/envs/comp135_2020f_env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /Users/zoehsieh/opt/miniconda3/envs/comp135_2020f_env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "

# %%
best_lasso = lasso.set_params(**lasso_searcher.best_params_)

best_lasso.fit(x_tr_NF, y_tr_N)
# Out:
# /Users/zoehsieh/opt/miniconda3/envs/comp135_2020f_env/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# LogisticRegression(max_iter=20, penalty='l1', random_state=101, solver='saga')

# %% [markdown]
# ### Table 3: Comparison of methods on the bag-of-words to sentiment classification task.
#
# Please report balanced accuracy on the train, valid, and test sets, to 3 digits of precision
#
# **Sample Output** (Feel free to print all values and organize them in any software)
#
# |**method**|**train**|**valid**|**test**|
# |:-|:-:|:-:|:-:|
# |L1-penalized LogisticRegression	|0.123	|0.456	|0.890|
# |best RandomForest	|0.123	|0.456	|0.890|
# |best Tree	|0.123	|0.456	|0.890|
# |simple Tree	|0.123	|0.456	|0.890|

# %%
# best tree

# train
yhat_best_tr = best_tree.predict(x_tr_NF)
print(sklearn.metrics.accuracy_score(y_tr_N, yhat_best_tr))


# valid
yhat_best_va = best_tree.predict(x_va_TF)
print(sklearn.metrics.accuracy_score(y_va_T, yhat_best_va))

# test
yhat_best_te = best_tree.predict(x_te_TF)
print(sklearn.metrics.accuracy_score(y_te_T, yhat_best_te))
# Out:
# 0.9981090450677592
# 0.7373737373737373
# 0.7263556116015133

# %%
# simple tree

# train
yhat_simple_tr = simple_tree.predict(x_tr_NF)
print(sklearn.metrics.accuracy_score(y_tr_N, yhat_simple_tr))


# valid
yhat_simple_va = simple_tree.predict(x_va_TF)
print(sklearn.metrics.accuracy_score(y_va_T, yhat_simple_va))

# test
yhat_simple_te = simple_tree.predict(x_te_TF)
print(sklearn.metrics.accuracy_score(y_te_T, yhat_simple_te))
# Out:
# 0.6459186889379136
# 0.648989898989899
# 0.639344262295082

# %%
# forest

# train
yhat_forest_tr = best_forest.predict(x_tr_NF)
print(sklearn.metrics.accuracy_score(y_tr_N, yhat_best_tr))


# valid
yhat_forest_va = best_forest.predict(x_va_TF)
print(sklearn.metrics.accuracy_score(y_va_T, yhat_best_va))

# test
yhat_forest_te = best_forest.predict(x_te_TF)
print(sklearn.metrics.accuracy_score(y_te_T, yhat_best_te))
# Out:
# 0.9981090450677592
# 0.7373737373737373
# 0.7263556116015133

# %%
# L1

# train
yhat_lasso_tr = best_lasso.predict(x_tr_NF)
print(sklearn.metrics.accuracy_score(y_tr_N, yhat_lasso_tr))


# valid
yhat_lasso_va = best_lasso.predict(x_va_TF)
print(sklearn.metrics.accuracy_score(y_va_T, yhat_lasso_va))

# test
yhat_lasso_te = best_forest.predict(x_te_TF)
print(sklearn.metrics.accuracy_score(y_te_T, yhat_lasso_te))
# Out:
# 0.9383863851244879
# 0.8712121212121212
# 0.819672131147541
